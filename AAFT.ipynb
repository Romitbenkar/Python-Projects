# %%
import requests
from bs4 import BeautifulSoup

url = "https://aaft.com/msc-interior-design"

# Send a GET request to the URL
response = requests.get(url)

if response.status_code == 200:  # Check if the request was successful
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, "html.parser")

    # Extract the course name
    course_name_element = soup.find("h1")
    if course_name_element:
        course_name = course_name_element.text.strip()
        print("Course Name:", course_name)
    else:
        print("Course name not found on the page.")
else:
    print("Failed to fetch the page. Status code:", response.status_code)
# Out:
# Course Name: M.Sc in Interior Design

# %%
import requests
from bs4 import BeautifulSoup

def extract_course_name(urls):
    course_names = []
    for url in urls:
        response = requests.get(url)
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            course_name_element = soup.find("h1")
            
            if course_name_element:
                course_name = course_name_element.text.strip()
                course_names.append(course_name)
            else:
                course_names.append("Course name not found on the page.")
        else:
            course_names.append(f"Failed to fetch the page. Status code: {response.status_code}")
    
    return course_names

# List of URLs to extract course names from
url_list = [
    "https://aaft.com/1-year-diploma-in-culinary-arts",
"https://aaft.com/bsc-in-sound-design",
"https://aaft.com/pg-diploma-in-tv-journalism-and-communication",
"https://aaft.com/schoolofinterior/programmes/pg-diploma-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-communication",
"https://aaft.com/ma-classical-vocal",
"https://aaft.com/ma-in-still-photography",
"https://aaft.com/msc-interior-design",
"https://aaft.com/msc-in-game-design-and-development",
"https://aaft.com/schooloffashion/programmes/masters-in-fashion-design-2-yrs",
"https://aaft.com/msc-in-data-science",
"https://aaft.com/schoolofanimation/programmes/m-sc-in-3d-animation",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-sound-editing",
"https://aaft.com/msc-in-cinema-and-pg-diploma-in-Post-Production(Video)",
"https://aaft.com/msc-in-digital-marketing",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-direction",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-cinematography",
"https://aaft.com/schoolofmasscommunication/programmes/ma-mass-communication",
"https://aaft.com/schoolofadvertising/programmes/ma-public-relations-events",
"https://aaft.com/schoolofadvertising/programmes/ma-advertising-brand-communication",
"https://aaft.com/diploma-in-westen-vocal-instrument",
"https://aaft.com/diploma-in-unreal-engine",
"https://aaft.com/schoolofmasscommunication/programmes/pgd-in-tv-journalism-communication",
"https://aaft.com/Diploma-in-tourism-and-travel",
"https://aaft.com/schoolofphotography/diploma-pg-diploma-in-photography",
"https://aaft.com/diploma-in-sound-design",
"https://aaft.com/diploma-in-pr-and-events",
"https://aaft.com/schoolofcinema/programmes/diploma-in-post-production",
"https://aaft.com/diploma-in-music-production",
"https://aaft.com/diploma-in-interior-design",
"https://aaft.com/diploma-in-instrumental-western-classical",
"https://aaft.com/schooloffinearts/diploma-in-classical-vocal-instrument",
"https://aaft.com/diploma-in-hotel-management",
"https://aaft.com/diploma-in-film-and-tv-production",
"https://aaft.com/schooloffashion/fashion-at-aaft",
"https://aaft.com/diploma-in-fashion-communication",
"https://aaft.com/diploma-in-djing",
"https://aaft.com/diploma-in-digital-marketing",
"https://aaft.com/diploma-in-data-science",
"https://aaft.com/6-months-diploma-in-culinary-arts",
"https://aaft.com/diploma-in-indian-classical-vocal-instrument",
"https://aaft.com/schoolofcinema/programmes/diploma-in-camera-lightning-techniques",
"https://aaft.com/diploma-in-animation-and-vfx",
"https://aaft.com/diploma-in-advertising-and-brand-communication",
"https://aaft.com/diploma-in-acting-and-presentation",
"https://aaft.com/diploma-in-sound-designing-3months",
"https://aaft.com/diploma-in-music-production-3months",
"https://aaft.com/schoolofcinema/video-editing-sound-recording",
"https://aaft.com/certificate-in-still-photography",
"https://aaft.com/schoolofcinema/programmes/screenplay-writing",
"https://aaft.com/schoolofmasscommunication/radio-jockey-rj",
"https://aaft.com/schoolofcinema/production-direction-tv-journalism",
"https://aaft.com/schoolofmasscommunication/news-anchoring-reporting",
"https://aaft.com/certificate-in-graphic-design",
"https://aaft.com/certificate-in-digital-marketing",
"https://aaft.com/certificate-in-camera-and-lighting-techniques",
"https://aaft.com/bachelors-of-tourism-and-travel-management",
"https://aaft.com/bachelors-of-hotel-management",
"https://aaft.com/schooloffinearts/programmes/bachelor-in-performing-arts",
"https://aaft.com/certificate-course-in-bakery",
"https://aaft.com/ba-in-indian-classical-vocal",
"https://aaft.com/ba-instrumental-music-guitar",
"https://aaft.com/schoolofadvertising/ba-in-event-management",
"https://aaft.com/schoolofinterior/programmes/b-sc-interior-design-diploma-in-interior-design",
"https://aaft.com/schoolofanimation/b-sc-in-game-design-development",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-communication-b-des-fashion-communication",
"https://aaft.com/bsc-in-digital-marketing",
"https://aaft.com/bsc-in-data-science",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-sound-editing",
"https://aaft.com/bsc-in-cinema-and-diploma-in-Post-Production(Video)",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-direction",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-cinematography",
"https://aaft.com/schoolofanimation/programmes/b-sc-in-3d-animation",
"https://aaft.com/schooloffashion/programmes/fashion-design",
"https://aaft.com/schoolofinterior/programmes/b-des-interior-design-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-design-b-des-fashion-design",
"https://aaft.com/ba-in-still-photography",
"https://aaft.com/ba-in-journalism-and-mass-communication",
"https://aaft.com/1-year-diploma-in-culinary-arts",

    # Add more URLs here
]

extracted_course_names = extract_course_name(url_list)

# Printing extracted course names
for index, course_name in enumerate(extracted_course_names, start=1):
    print(f"Course {index} Name: {course_name}")
# Out:
# Course 1 Name: 1-year Diploma in Culinary Arts
# Course 2 Name: B.Sc Sound Design
# Course 3 Name: PG Diploma in TV Journalism and Communication
# Course 4 Name: PG Diploma in Interior Design
# Course 5 Name: PG diploma in Fashion Design
# Course 6 Name: PG Diploma in Fashion Communication
# Course 7 Name: MA Vocal (Specialization In Classical/Western Vocal)
# Course 8 Name: MA in Still Photography
# Course 9 Name: M.Sc in Interior Design
# Course 10 Name: M.Sc in Game Design and Development
# Course 11 Name: M.Sc in Fashion and Design
# Course 12 Name: M.Sc in Data Science
# Course 13 Name: M.Sc in Animation and VFX
# Course 14 Name: M.Sc Cinema (Specialization In Sound Editing)
# Course 15 Name: M.Sc Cinema (Specialization In Post-Production)
# Course 16 Name: M.Sc in Digital Marketing
# Course 17 Name: M.Sc Cinema (Specialization In Direction)
# Course 18 Name: M.Sc Cinema (Specialization In Cinematography)
# Course 19 Name: M.A. in Journalism and Mass Communication
# ...

# %%
#Course Name
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_course_name(urls):
    data = []
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            course_name_element = soup.find("h1")
            if course_name_element:
                course_name = course_name_element.text.strip()
                data.append({"URL": url, "Course Name": course_name})
            else:
                data.append({"URL": url, "Course Name": "Course name not found on the page."})
        else:
            data.append({"URL": url, "Course Name": f"Failed to fetch the page. Status code: {response.status_code}"})
    
    return data

# List of URLs to extract course names from
url_list = [
"https://aaft.com/1-year-diploma-in-culinary-arts",
"https://aaft.com/bsc-in-sound-design",
"https://aaft.com/pg-diploma-in-tv-journalism-and-communication",
"https://aaft.com/schoolofinterior/programmes/pg-diploma-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-communication",
"https://aaft.com/ma-classical-vocal",
"https://aaft.com/ma-in-still-photography",
"https://aaft.com/msc-interior-design",
"https://aaft.com/msc-in-game-design-and-development",
"https://aaft.com/schooloffashion/programmes/masters-in-fashion-design-2-yrs",
"https://aaft.com/msc-in-data-science",
"https://aaft.com/schoolofanimation/programmes/m-sc-in-3d-animation",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-sound-editing",
"https://aaft.com/msc-in-cinema-and-pg-diploma-in-Post-Production(Video)",
"https://aaft.com/msc-in-digital-marketing",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-direction",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-cinematography",
"https://aaft.com/schoolofmasscommunication/programmes/ma-mass-communication",
"https://aaft.com/schoolofadvertising/programmes/ma-public-relations-events",
"https://aaft.com/schoolofadvertising/programmes/ma-advertising-brand-communication",
"https://aaft.com/diploma-in-westen-vocal-instrument",
"https://aaft.com/diploma-in-unreal-engine",
"https://aaft.com/schoolofmasscommunication/programmes/pgd-in-tv-journalism-communication",
"https://aaft.com/Diploma-in-tourism-and-travel",
"https://aaft.com/schoolofphotography/diploma-pg-diploma-in-photography",
"https://aaft.com/diploma-in-sound-design",
"https://aaft.com/diploma-in-pr-and-events",
"https://aaft.com/schoolofcinema/programmes/diploma-in-post-production",
"https://aaft.com/diploma-in-music-production",
"https://aaft.com/diploma-in-interior-design",
"https://aaft.com/diploma-in-instrumental-western-classical",
"https://aaft.com/schooloffinearts/diploma-in-classical-vocal-instrument",
"https://aaft.com/diploma-in-hotel-management",
"https://aaft.com/diploma-in-film-and-tv-production",
"https://aaft.com/schooloffashion/fashion-at-aaft",
"https://aaft.com/diploma-in-fashion-communication",
"https://aaft.com/diploma-in-djing",
"https://aaft.com/diploma-in-digital-marketing",
"https://aaft.com/diploma-in-data-science",
"https://aaft.com/6-months-diploma-in-culinary-arts",
"https://aaft.com/diploma-in-indian-classical-vocal-instrument",
"https://aaft.com/schoolofcinema/programmes/diploma-in-camera-lightning-techniques",
"https://aaft.com/diploma-in-animation-and-vfx",
"https://aaft.com/diploma-in-advertising-and-brand-communication",
"https://aaft.com/diploma-in-acting-and-presentation",
"https://aaft.com/diploma-in-sound-designing-3months",
"https://aaft.com/diploma-in-music-production-3months",
"https://aaft.com/schoolofcinema/video-editing-sound-recording",
"https://aaft.com/certificate-in-still-photography",
"https://aaft.com/schoolofcinema/programmes/screenplay-writing",
"https://aaft.com/schoolofmasscommunication/radio-jockey-rj",
"https://aaft.com/schoolofcinema/production-direction-tv-journalism",
"https://aaft.com/schoolofmasscommunication/news-anchoring-reporting",
"https://aaft.com/certificate-in-graphic-design",
"https://aaft.com/certificate-in-digital-marketing",
"https://aaft.com/certificate-in-camera-and-lighting-techniques",
"https://aaft.com/bachelors-of-tourism-and-travel-management",
"https://aaft.com/bachelors-of-hotel-management",
"https://aaft.com/schooloffinearts/programmes/bachelor-in-performing-arts",
"https://aaft.com/certificate-course-in-bakery",
"https://aaft.com/ba-in-indian-classical-vocal",
"https://aaft.com/ba-instrumental-music-guitar",
"https://aaft.com/schoolofadvertising/ba-in-event-management",
"https://aaft.com/schoolofinterior/programmes/b-sc-interior-design-diploma-in-interior-design",
"https://aaft.com/schoolofanimation/b-sc-in-game-design-development",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-communication-b-des-fashion-communication",
"https://aaft.com/bsc-in-digital-marketing",
"https://aaft.com/bsc-in-data-science",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-sound-editing",
"https://aaft.com/bsc-in-cinema-and-diploma-in-Post-Production(Video)",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-direction",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-cinematography",
"https://aaft.com/schoolofanimation/programmes/b-sc-in-3d-animation",
"https://aaft.com/schooloffashion/programmes/fashion-design",
"https://aaft.com/schoolofinterior/programmes/b-des-interior-design-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-design-b-des-fashion-design",
"https://aaft.com/ba-in-still-photography",
"https://aaft.com/ba-in-journalism-and-mass-communication",
"https://aaft.com/1-year-diploma-in-culinary-arts",

    # Add more URLs here
]

extracted_data = extract_course_name(url_list)

# Create a DataFrame from the extracted data
df = pd.DataFrame(extracted_data)

# Export the DataFrame to an Excel file
excel_file = "AAFTcourse_names.xlsx"
df.to_excel(excel_file, index=False)

print(f"Data extracted and saved to '{excel_file}'")
# Out:
# Data extracted and saved to 'AAFTcourse_names.xlsx'

# %%
import requests
from bs4 import BeautifulSoup

def extract_about_course(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        
        about_course_element = soup.find("div", class_="about-details")
        if about_course_element:
            about_course = about_course_element.find("p").text.strip()
            return about_course
        else:
            return "About course details not found on the page."
    else:
        return f"Failed to fetch the page. Status code: {response.status_code}"

# URL to extract "About Course" information from
url = "https://aaft.com/msc-interior-design"

about_course_info = extract_about_course(url)
print("About Course:")
print(about_course_info)
# Out:
# About Course:
# Learn the art of transforming simple spaces into beautiful representationss of an individual’s dreams with this 2-year Master’s in Interior Design program at the AAFT School of Fashion and Design. This course will help you gain expertise in interior designing by integrating expert knowledge and the latest technology to promote creative and out-of-the-box thinking. Ultimately, the School aims to create a new generation of designers that will illuminate the world of interior design with their unique ideas.

# %%
import requests
from bs4 import BeautifulSoup

def extract_about_course(urls):
    data = []
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            about_course_element = soup.find("div", class_="about-details")
            if about_course_element:
                about_course = about_course_element.find("p").text.strip()
                data.append({"URL": url, "About Course": about_course})
            else:
                data.append({"URL": url, "About Course": "About course details not found on the page."})
        else:
            data.append({"URL": url, "About Course": f"Failed to fetch the page. Status code: {response.status_code}"})
    
    return data

# List of URLs to extract "About Course" information from
url_list = [
    "https://aaft.com/msc-interior-design",
    # Add more URLs here
]

extracted_data = extract_about_course(url_list)

# Printing extracted "About Course" information
for index, info in enumerate(extracted_data, start=1):
    print(f"URL {index}: {info['URL']}")
    print(f"About Course {index}: {info['About Course']}")
    print("\n")
# Out:
# URL 1: https://aaft.com/msc-interior-design
# About Course 1: Learn the art of transforming simple spaces into beautiful representationss of an individual’s dreams with this 2-year Master’s in Interior Design program at the AAFT School of Fashion and Design. This course will help you gain expertise in interior designing by integrating expert knowledge and the latest technology to promote creative and out-of-the-box thinking. Ultimately, the School aims to create a new generation of designers that will illuminate the world of interior design with their unique ideas.

# %%
#About Course
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_about_course(urls):
    data = []
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            about_course_element = soup.find("div", class_="about-details")
            if about_course_element:
                about_course = about_course_element.find("p").text.strip()
                data.append({"URL": url, "About Course": about_course})
            else:
                data.append({"URL": url, "About Course": "About course details not found on the page."})
        else:
            data.append({"URL": url, "About Course": f"Failed to fetch the page. Status code: {response.status_code}"})
    
    return data

# List of URLs to extract "About Course" information from
url_list = [
"https://aaft.com/1-year-diploma-in-culinary-arts",
"https://aaft.com/bsc-in-sound-design",
"https://aaft.com/pg-diploma-in-tv-journalism-and-communication",
"https://aaft.com/schoolofinterior/programmes/pg-diploma-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-communication",
"https://aaft.com/ma-classical-vocal",
"https://aaft.com/ma-in-still-photography",
"https://aaft.com/msc-interior-design",
"https://aaft.com/msc-in-game-design-and-development",
"https://aaft.com/schooloffashion/programmes/masters-in-fashion-design-2-yrs",
"https://aaft.com/msc-in-data-science",
"https://aaft.com/schoolofanimation/programmes/m-sc-in-3d-animation",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-sound-editing",
"https://aaft.com/msc-in-cinema-and-pg-diploma-in-Post-Production(Video)",
"https://aaft.com/msc-in-digital-marketing",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-direction",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-cinematography",
"https://aaft.com/schoolofmasscommunication/programmes/ma-mass-communication",
"https://aaft.com/schoolofadvertising/programmes/ma-public-relations-events",
"https://aaft.com/schoolofadvertising/programmes/ma-advertising-brand-communication",
"https://aaft.com/diploma-in-westen-vocal-instrument",
"https://aaft.com/diploma-in-unreal-engine",
"https://aaft.com/schoolofmasscommunication/programmes/pgd-in-tv-journalism-communication",
"https://aaft.com/Diploma-in-tourism-and-travel",
"https://aaft.com/schoolofphotography/diploma-pg-diploma-in-photography",
"https://aaft.com/diploma-in-sound-design",
"https://aaft.com/diploma-in-pr-and-events",
"https://aaft.com/schoolofcinema/programmes/diploma-in-post-production",
"https://aaft.com/diploma-in-music-production",
"https://aaft.com/diploma-in-interior-design",
"https://aaft.com/diploma-in-instrumental-western-classical",
"https://aaft.com/schooloffinearts/diploma-in-classical-vocal-instrument",
"https://aaft.com/diploma-in-hotel-management",
"https://aaft.com/diploma-in-film-and-tv-production",
"https://aaft.com/schooloffashion/fashion-at-aaft",
"https://aaft.com/diploma-in-fashion-communication",
"https://aaft.com/diploma-in-djing",
"https://aaft.com/diploma-in-digital-marketing",
"https://aaft.com/diploma-in-data-science",
"https://aaft.com/6-months-diploma-in-culinary-arts",
"https://aaft.com/diploma-in-indian-classical-vocal-instrument",
"https://aaft.com/schoolofcinema/programmes/diploma-in-camera-lightning-techniques",
"https://aaft.com/diploma-in-animation-and-vfx",
"https://aaft.com/diploma-in-advertising-and-brand-communication",
"https://aaft.com/diploma-in-acting-and-presentation",
"https://aaft.com/diploma-in-sound-designing-3months",
"https://aaft.com/diploma-in-music-production-3months",
"https://aaft.com/schoolofcinema/video-editing-sound-recording",
"https://aaft.com/certificate-in-still-photography",
"https://aaft.com/schoolofcinema/programmes/screenplay-writing",
"https://aaft.com/schoolofmasscommunication/radio-jockey-rj",
"https://aaft.com/schoolofcinema/production-direction-tv-journalism",
"https://aaft.com/schoolofmasscommunication/news-anchoring-reporting",
"https://aaft.com/certificate-in-graphic-design",
"https://aaft.com/certificate-in-digital-marketing",
"https://aaft.com/certificate-in-camera-and-lighting-techniques",
"https://aaft.com/bachelors-of-tourism-and-travel-management",
"https://aaft.com/bachelors-of-hotel-management",
"https://aaft.com/schooloffinearts/programmes/bachelor-in-performing-arts",
"https://aaft.com/certificate-course-in-bakery",
"https://aaft.com/ba-in-indian-classical-vocal",
"https://aaft.com/ba-instrumental-music-guitar",
"https://aaft.com/schoolofadvertising/ba-in-event-management",
"https://aaft.com/schoolofinterior/programmes/b-sc-interior-design-diploma-in-interior-design",
"https://aaft.com/schoolofanimation/b-sc-in-game-design-development",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-communication-b-des-fashion-communication",
"https://aaft.com/bsc-in-digital-marketing",
"https://aaft.com/bsc-in-data-science",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-sound-editing",
"https://aaft.com/bsc-in-cinema-and-diploma-in-Post-Production(Video)",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-direction",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-cinematography",
"https://aaft.com/schoolofanimation/programmes/b-sc-in-3d-animation",
"https://aaft.com/schooloffashion/programmes/fashion-design",
"https://aaft.com/schoolofinterior/programmes/b-des-interior-design-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-design-b-des-fashion-design",
"https://aaft.com/ba-in-still-photography",
"https://aaft.com/ba-in-journalism-and-mass-communication",
"https://aaft.com/1-year-diploma-in-culinary-arts",

]

extracted_data = extract_about_course(url_list)

# Create a DataFrame from the extracted data
df = pd.DataFrame(extracted_data)

# Export the DataFrame to an Excel file
excel_file = "AAFTabout_course.xlsx"
df.to_excel(excel_file, index=False)

print(f"Data extracted and saved to '{excel_file}'")
# Out:
# Data extracted and saved to 'AAFTabout_course.xlsx'

# %%
import requests
from bs4 import BeautifulSoup

def extract_course_syllabus(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        
        syllabus_div = soup.find("div", id="accordion")
        if syllabus_div:
            syllabus_items = syllabus_div.find_all("div", class_="card")
            course_syllabus = ""
            for item in syllabus_items:
                header = item.find("div", class_="card-header")
                semester = header.text.strip()
                body = item.find("div", class_="card-body")
                details = body.find_all("li")
                course_syllabus += f"{semester}\n"
                for detail in details:
                    course_syllabus += f"{detail.text.strip()}\n"
                course_syllabus += "\n"
            
            return course_syllabus
        else:
            return "Course syllabus details not found on the page."
    else:
        return f"Failed to fetch the page. Status code: {response.status_code}"

# URL to extract "Course Syllabus" information from
url = "https://aaft.com/msc-interior-design"

course_syllabus_info = extract_course_syllabus(url)
print("Course Syllabus:")
print(course_syllabus_info)
# Out:
# Course Syllabus:
# Semester 1
# Gaining a clear understanding of different elements of interior design.
# Developing knowledge about different kinds of materials used in building construction.
# Understanding the ergonomics, materials, design, and working parameters of designing furniture.
# Gaining expertise in using architectural symbols.
# Learning about the state laws with reference to residential accommodations.
#
# Semester 2
# Field visits to monuments and temples to study their architectural styles and learning to take inspiration from history for their designs.
# Learning the science of Vaastu Shastra and how to apply it in interior designing.
# Learning about arches, staircases, panels, partitions, etc., that are useful for technical and design knowledge.
# Learning about the scientific ways of designing two types of furniture systems - for storage purposes and for sitting purposes.
# Understand plotting, manipulation, variations in design by computer-aided designing.
# ...

# %%
import requests
from bs4 import BeautifulSoup

def extract_course_syllabus(urls):
    data = []
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            syllabus_div = soup.find("div", id="accordion")
            if syllabus_div:
                syllabus_items = syllabus_div.find_all("div", class_="card")
                course_syllabus = ""
                for item in syllabus_items:
                    header = item.find("div", class_="card-header")
                    semester = header.text.strip()
                    body = item.find("div", class_="card-body")
                    details = body.find_all("li")
                    course_syllabus += f"{semester}\n"
                    for detail in details:
                        course_syllabus += f"{detail.text.strip()}\n"
                    course_syllabus += "\n"
                data.append({"URL": url, "Course Syllabus": course_syllabus})
            else:
                data.append({"URL": url, "Course Syllabus": "Course syllabus details not found on the page."})
        else:
            data.append({"URL": url, "Course Syllabus": f"Failed to fetch the page. Status code: {response.status_code}"})
    
    return data

# List of URLs to extract "Course Syllabus" information from
url_list = [
 "https://aaft.com/1-year-diploma-in-culinary-arts",
"https://aaft.com/bsc-in-sound-design",
"https://aaft.com/pg-diploma-in-tv-journalism-and-communication",
"https://aaft.com/schoolofinterior/programmes/pg-diploma-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-communication",
"https://aaft.com/ma-classical-vocal",
"https://aaft.com/ma-in-still-photography",
"https://aaft.com/msc-interior-design",
"https://aaft.com/msc-in-game-design-and-development",
"https://aaft.com/schooloffashion/programmes/masters-in-fashion-design-2-yrs",
"https://aaft.com/msc-in-data-science",
"https://aaft.com/schoolofanimation/programmes/m-sc-in-3d-animation",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-sound-editing",
"https://aaft.com/msc-in-cinema-and-pg-diploma-in-Post-Production(Video)",
"https://aaft.com/msc-in-digital-marketing",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-direction",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-cinematography",
"https://aaft.com/schoolofmasscommunication/programmes/ma-mass-communication",
"https://aaft.com/schoolofadvertising/programmes/ma-public-relations-events",
"https://aaft.com/schoolofadvertising/programmes/ma-advertising-brand-communication",
"https://aaft.com/diploma-in-westen-vocal-instrument",
"https://aaft.com/diploma-in-unreal-engine",
"https://aaft.com/schoolofmasscommunication/programmes/pgd-in-tv-journalism-communication",
"https://aaft.com/Diploma-in-tourism-and-travel",
"https://aaft.com/schoolofphotography/diploma-pg-diploma-in-photography",
"https://aaft.com/diploma-in-sound-design",
"https://aaft.com/diploma-in-pr-and-events",
"https://aaft.com/schoolofcinema/programmes/diploma-in-post-production",
"https://aaft.com/diploma-in-music-production",
"https://aaft.com/diploma-in-interior-design",
"https://aaft.com/diploma-in-instrumental-western-classical",
"https://aaft.com/schooloffinearts/diploma-in-classical-vocal-instrument",
"https://aaft.com/diploma-in-hotel-management",
"https://aaft.com/diploma-in-film-and-tv-production",
"https://aaft.com/schooloffashion/fashion-at-aaft",
"https://aaft.com/diploma-in-fashion-communication",
"https://aaft.com/diploma-in-djing",
"https://aaft.com/diploma-in-digital-marketing",
"https://aaft.com/diploma-in-data-science",
"https://aaft.com/6-months-diploma-in-culinary-arts",
"https://aaft.com/diploma-in-indian-classical-vocal-instrument",
"https://aaft.com/schoolofcinema/programmes/diploma-in-camera-lightning-techniques",
"https://aaft.com/diploma-in-animation-and-vfx",
"https://aaft.com/diploma-in-advertising-and-brand-communication",
"https://aaft.com/diploma-in-acting-and-presentation",
"https://aaft.com/diploma-in-sound-designing-3months",
"https://aaft.com/diploma-in-music-production-3months",
"https://aaft.com/schoolofcinema/video-editing-sound-recording",
"https://aaft.com/certificate-in-still-photography",
"https://aaft.com/schoolofcinema/programmes/screenplay-writing",
"https://aaft.com/schoolofmasscommunication/radio-jockey-rj",
"https://aaft.com/schoolofcinema/production-direction-tv-journalism",
"https://aaft.com/schoolofmasscommunication/news-anchoring-reporting",
"https://aaft.com/certificate-in-graphic-design",
"https://aaft.com/certificate-in-digital-marketing",
"https://aaft.com/certificate-in-camera-and-lighting-techniques",
"https://aaft.com/bachelors-of-tourism-and-travel-management",
"https://aaft.com/bachelors-of-hotel-management",
"https://aaft.com/schooloffinearts/programmes/bachelor-in-performing-arts",
"https://aaft.com/certificate-course-in-bakery",
"https://aaft.com/ba-in-indian-classical-vocal",
"https://aaft.com/ba-instrumental-music-guitar",
"https://aaft.com/schoolofadvertising/ba-in-event-management",
"https://aaft.com/schoolofinterior/programmes/b-sc-interior-design-diploma-in-interior-design",
"https://aaft.com/schoolofanimation/b-sc-in-game-design-development",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-communication-b-des-fashion-communication",
"https://aaft.com/bsc-in-digital-marketing",
"https://aaft.com/bsc-in-data-science",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-sound-editing",
"https://aaft.com/bsc-in-cinema-and-diploma-in-Post-Production(Video)",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-direction",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-cinematography",
"https://aaft.com/schoolofanimation/programmes/b-sc-in-3d-animation",
"https://aaft.com/schooloffashion/programmes/fashion-design",
"https://aaft.com/schoolofinterior/programmes/b-des-interior-design-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-design-b-des-fashion-design",
"https://aaft.com/ba-in-still-photography",
"https://aaft.com/ba-in-journalism-and-mass-communication",
"https://aaft.com/1-year-diploma-in-culinary-arts",

]

extracted_data = extract_course_syllabus(url_list)

# Printing extracted "Course Syllabus" information
for index, info in enumerate(extracted_data, start=1):
    print(f"URL {index}: {info['URL']}")
    print(f"Course Syllabus {index}:\n{info['Course Syllabus']}")
    print("\n")
# Out:
# URL 1: https://aaft.com/1-year-diploma-in-culinary-arts
# Course Syllabus 1:
# Semester 1
# Understanding the importance of personal hygiene, appearance, and grooming.
# Introduction to kitchen tools and equipment like cleaning and maintenance tools, types of knives, etc.
# Knowing about different types of ingredients used in bakery and confectionery.
# Types of ovens and their different temperatures.
# Learning about different types of ingredients used in bread making.
# Different types of bread: Foccassia Bread, Ciabatta Bread, Multi-Grain Bread, French loaf, bread rolls, pizza base.
# Introduction cake and pastry making
# Role of different types of icing in cake baking like Ganache, Buttercream, Fondant, Royal, Mirror Glaze.
# Learning different methods of making cookies.
# Knowing about the difference between cookies and biscuits.
# Learning different types of cookies and biscuits like salted, ice-box, piping, rolling, macrons, and tarts.
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_course_syllabus(urls):
    data = []
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            syllabus_div = soup.find("div", id="accordion")
            if syllabus_div:
                syllabus_items = syllabus_div.find_all("div", class_="card")
                course_syllabus = ""
                for item in syllabus_items:
                    header = item.find("div", class_="card-header")
                    semester = header.text.strip()
                    body = item.find("div", class_="card-body")
                    details = body.find_all("li")
                    course_syllabus += f"{semester}\n"
                    for detail in details:
                        course_syllabus += f"{detail.text.strip()}\n"
                    course_syllabus += "\n"
                data.append({"URL": url, "Course Syllabus": course_syllabus})
            else:
                data.append({"URL": url, "Course Syllabus": "Course syllabus details not found on the page."})
        else:
            data.append({"URL": url, "Course Syllabus": f"Failed to fetch the page. Status code: {response.status_code}"})
    
    return data

# List of URLs to extract "Course Syllabus" information from
url_list = [
    "https://aaft.com/1-year-diploma-in-culinary-arts",
"https://aaft.com/bsc-in-sound-design",
"https://aaft.com/pg-diploma-in-tv-journalism-and-communication",
"https://aaft.com/schoolofinterior/programmes/pg-diploma-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-communication",
"https://aaft.com/ma-classical-vocal",
"https://aaft.com/ma-in-still-photography",
"https://aaft.com/msc-interior-design",
"https://aaft.com/msc-in-game-design-and-development",
"https://aaft.com/schooloffashion/programmes/masters-in-fashion-design-2-yrs",
"https://aaft.com/msc-in-data-science",
"https://aaft.com/schoolofanimation/programmes/m-sc-in-3d-animation",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-sound-editing",
"https://aaft.com/msc-in-cinema-and-pg-diploma-in-Post-Production(Video)",
"https://aaft.com/msc-in-digital-marketing",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-direction",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-cinematography",
"https://aaft.com/schoolofmasscommunication/programmes/ma-mass-communication",
"https://aaft.com/schoolofadvertising/programmes/ma-public-relations-events",
"https://aaft.com/schoolofadvertising/programmes/ma-advertising-brand-communication",
"https://aaft.com/diploma-in-westen-vocal-instrument",
"https://aaft.com/diploma-in-unreal-engine",
"https://aaft.com/schoolofmasscommunication/programmes/pgd-in-tv-journalism-communication",
"https://aaft.com/Diploma-in-tourism-and-travel",
"https://aaft.com/schoolofphotography/diploma-pg-diploma-in-photography",
"https://aaft.com/diploma-in-sound-design",
"https://aaft.com/diploma-in-pr-and-events",
"https://aaft.com/schoolofcinema/programmes/diploma-in-post-production",
"https://aaft.com/diploma-in-music-production",
"https://aaft.com/diploma-in-interior-design",
"https://aaft.com/diploma-in-instrumental-western-classical",
"https://aaft.com/schooloffinearts/diploma-in-classical-vocal-instrument",
"https://aaft.com/diploma-in-hotel-management",
"https://aaft.com/diploma-in-film-and-tv-production",
"https://aaft.com/schooloffashion/fashion-at-aaft",
"https://aaft.com/diploma-in-fashion-communication",
"https://aaft.com/diploma-in-djing",
"https://aaft.com/diploma-in-digital-marketing",
"https://aaft.com/diploma-in-data-science",
"https://aaft.com/6-months-diploma-in-culinary-arts",
"https://aaft.com/diploma-in-indian-classical-vocal-instrument",
"https://aaft.com/schoolofcinema/programmes/diploma-in-camera-lightning-techniques",
"https://aaft.com/diploma-in-animation-and-vfx",
"https://aaft.com/diploma-in-advertising-and-brand-communication",
"https://aaft.com/diploma-in-acting-and-presentation",
"https://aaft.com/diploma-in-sound-designing-3months",
"https://aaft.com/diploma-in-music-production-3months",
"https://aaft.com/schoolofcinema/video-editing-sound-recording",
"https://aaft.com/certificate-in-still-photography",
"https://aaft.com/schoolofcinema/programmes/screenplay-writing",
"https://aaft.com/schoolofmasscommunication/radio-jockey-rj",
"https://aaft.com/schoolofcinema/production-direction-tv-journalism",
"https://aaft.com/schoolofmasscommunication/news-anchoring-reporting",
"https://aaft.com/certificate-in-graphic-design",
"https://aaft.com/certificate-in-digital-marketing",
"https://aaft.com/certificate-in-camera-and-lighting-techniques",
"https://aaft.com/bachelors-of-tourism-and-travel-management",
"https://aaft.com/bachelors-of-hotel-management",
"https://aaft.com/schooloffinearts/programmes/bachelor-in-performing-arts",
"https://aaft.com/certificate-course-in-bakery",
"https://aaft.com/ba-in-indian-classical-vocal",
"https://aaft.com/ba-instrumental-music-guitar",
"https://aaft.com/schoolofadvertising/ba-in-event-management",
"https://aaft.com/schoolofinterior/programmes/b-sc-interior-design-diploma-in-interior-design",
"https://aaft.com/schoolofanimation/b-sc-in-game-design-development",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-communication-b-des-fashion-communication",
"https://aaft.com/bsc-in-digital-marketing",
"https://aaft.com/bsc-in-data-science",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-sound-editing",
"https://aaft.com/bsc-in-cinema-and-diploma-in-Post-Production(Video)",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-direction",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-cinematography",
"https://aaft.com/schoolofanimation/programmes/b-sc-in-3d-animation",
"https://aaft.com/schooloffashion/programmes/fashion-design",
"https://aaft.com/schoolofinterior/programmes/b-des-interior-design-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-design-b-des-fashion-design",
"https://aaft.com/ba-in-still-photography",
"https://aaft.com/ba-in-journalism-and-mass-communication",
"https://aaft.com/1-year-diploma-in-culinary-arts",

    # Add more URLs here
]

extracted_data = extract_course_syllabus(url_list)

# Create a DataFrame from the extracted data
df = pd.DataFrame(extracted_data)

# Export the DataFrame to an Excel file
excel_file = "AAFTcourse_syllabus.xlsx"
df.to_excel(excel_file, index=False)

print(f"Data extracted and saved to '{excel_file}'")
# Out:
# Data extracted and saved to 'AAFTcourse_syllabus.xlsx'

# %%
import requests
from bs4 import BeautifulSoup

def extract_course_faculty(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        
        faculty_section = soup.find("section", id="faculty-section")
        if faculty_section:
            faculty_items = faculty_section.find_all("div", class_="col-sm-3")
            course_faculty = ""
            for item in faculty_items:
                faculty_name = item.find("h4").text.strip()
                faculty_role = item.find("span").text.strip()
                course_faculty += f"{faculty_name}\n{faculty_role}\n\n"
            return course_faculty
        else:
            return "Course faculty details not found on the page."
    else:
        return f"Failed to fetch the page. Status code: {response.status_code}"

# URL to extract "Course Faculty" information from
url = "https://aaft.com/msc-interior-design"

course_faculty_info = extract_course_faculty(url)
print("Course Faculty:")
print(course_faculty_info)
# Out:
# Course Faculty:
# Mr. Jayesh D. Wadia
# DEAN | SOID, AAFT
#
# Ms Neetu Teotia
# HOD, Interior Design
#
# Ms. Renu Premi
# Assistant Professor
#
# Ms. Divya Bhatt
# Assistant Professor
#
# Ms. Malika
# Assistant Professor
#
# Ms. Ridhi Dixit
# Assistant Professor

# %%
import requests
from bs4 import BeautifulSoup

def extract_course_faculty(urls):
    data = []
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            faculty_section = soup.find("section", id="faculty-section")
            if faculty_section:
                faculty_items = faculty_section.find_all("div", class_="col-sm-3")
                course_faculty = ""
                for item in faculty_items:
                    faculty_name = item.find("h4").text.strip()
                    faculty_role = item.find("span").text.strip()
                    course_faculty += f"{faculty_name}\n{faculty_role}\n\n"
                data.append({"URL": url, "Course Faculty": course_faculty})
            else:
                data.append({"URL": url, "Course Faculty": "Course faculty details not found on the page."})
        else:
            data.append({"URL": url, "Course Faculty": f"Failed to fetch the page. Status code: {response.status_code}"})
    
    return data

# List of URLs to extract "Course Faculty" information from
url_list = [
 "https://aaft.com/1-year-diploma-in-culinary-arts",
"https://aaft.com/bsc-in-sound-design",
"https://aaft.com/pg-diploma-in-tv-journalism-and-communication",
"https://aaft.com/schoolofinterior/programmes/pg-diploma-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-communication",
"https://aaft.com/ma-classical-vocal",
"https://aaft.com/ma-in-still-photography",
"https://aaft.com/msc-interior-design",
"https://aaft.com/msc-in-game-design-and-development",
"https://aaft.com/schooloffashion/programmes/masters-in-fashion-design-2-yrs",
"https://aaft.com/msc-in-data-science",
"https://aaft.com/schoolofanimation/programmes/m-sc-in-3d-animation",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-sound-editing",
"https://aaft.com/msc-in-cinema-and-pg-diploma-in-Post-Production(Video)",
"https://aaft.com/msc-in-digital-marketing",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-direction",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-cinematography",
"https://aaft.com/schoolofmasscommunication/programmes/ma-mass-communication",
"https://aaft.com/schoolofadvertising/programmes/ma-public-relations-events",
"https://aaft.com/schoolofadvertising/programmes/ma-advertising-brand-communication",
"https://aaft.com/diploma-in-westen-vocal-instrument",
"https://aaft.com/diploma-in-unreal-engine",
"https://aaft.com/schoolofmasscommunication/programmes/pgd-in-tv-journalism-communication",
"https://aaft.com/Diploma-in-tourism-and-travel",
"https://aaft.com/schoolofphotography/diploma-pg-diploma-in-photography",
"https://aaft.com/diploma-in-sound-design",
"https://aaft.com/diploma-in-pr-and-events",
"https://aaft.com/schoolofcinema/programmes/diploma-in-post-production",
"https://aaft.com/diploma-in-music-production",
"https://aaft.com/diploma-in-interior-design",
"https://aaft.com/diploma-in-instrumental-western-classical",
"https://aaft.com/schooloffinearts/diploma-in-classical-vocal-instrument",
"https://aaft.com/diploma-in-hotel-management",
"https://aaft.com/diploma-in-film-and-tv-production",
"https://aaft.com/schooloffashion/fashion-at-aaft",
"https://aaft.com/diploma-in-fashion-communication",
"https://aaft.com/diploma-in-djing",
"https://aaft.com/diploma-in-digital-marketing",
"https://aaft.com/diploma-in-data-science",
"https://aaft.com/6-months-diploma-in-culinary-arts",
"https://aaft.com/diploma-in-indian-classical-vocal-instrument",
"https://aaft.com/schoolofcinema/programmes/diploma-in-camera-lightning-techniques",
"https://aaft.com/diploma-in-animation-and-vfx",
"https://aaft.com/diploma-in-advertising-and-brand-communication",
"https://aaft.com/diploma-in-acting-and-presentation",
"https://aaft.com/diploma-in-sound-designing-3months",
"https://aaft.com/diploma-in-music-production-3months",
"https://aaft.com/schoolofcinema/video-editing-sound-recording",
"https://aaft.com/certificate-in-still-photography",
"https://aaft.com/schoolofcinema/programmes/screenplay-writing",
"https://aaft.com/schoolofmasscommunication/radio-jockey-rj",
"https://aaft.com/schoolofcinema/production-direction-tv-journalism",
"https://aaft.com/schoolofmasscommunication/news-anchoring-reporting",
"https://aaft.com/certificate-in-graphic-design",
"https://aaft.com/certificate-in-digital-marketing",
"https://aaft.com/certificate-in-camera-and-lighting-techniques",
"https://aaft.com/bachelors-of-tourism-and-travel-management",
"https://aaft.com/bachelors-of-hotel-management",
"https://aaft.com/schooloffinearts/programmes/bachelor-in-performing-arts",
"https://aaft.com/certificate-course-in-bakery",
"https://aaft.com/ba-in-indian-classical-vocal",
"https://aaft.com/ba-instrumental-music-guitar",
"https://aaft.com/schoolofadvertising/ba-in-event-management",
"https://aaft.com/schoolofinterior/programmes/b-sc-interior-design-diploma-in-interior-design",
"https://aaft.com/schoolofanimation/b-sc-in-game-design-development",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-communication-b-des-fashion-communication",
"https://aaft.com/bsc-in-digital-marketing",
"https://aaft.com/bsc-in-data-science",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-sound-editing",
"https://aaft.com/bsc-in-cinema-and-diploma-in-Post-Production(Video)",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-direction",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-cinematography",
"https://aaft.com/schoolofanimation/programmes/b-sc-in-3d-animation",
"https://aaft.com/schooloffashion/programmes/fashion-design",
"https://aaft.com/schoolofinterior/programmes/b-des-interior-design-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-design-b-des-fashion-design",
"https://aaft.com/ba-in-still-photography",
"https://aaft.com/ba-in-journalism-and-mass-communication",
"https://aaft.com/1-year-diploma-in-culinary-arts",

    # Add more URLs here
]

extracted_data = extract_course_faculty(url_list)

# Printing extracted "Course Faculty" information
for index, info in enumerate(extracted_data, start=1):
    print(f"URL {index}: {info['URL']}")
    print(f"Course Faculty {index}:\n{info['Course Faculty']}")
    print("\n")
# Out:
# URL 1: https://aaft.com/1-year-diploma-in-culinary-arts
# Course Faculty 1:
# Ms Shipra
# Associate Professor
#
# Dr. Akriti Singh
# Associate Professor
#
# Ms Meenal Sharma
# Assistant Professor
#
# Chef Pankaj Kumar Singh
# Assistant Professor
#
# Ms Shefali Narang
# Assistant Professor
#
# Ms Aaditi Kashyap
# Assistant Professor
#
# Chef Amit Kumar
# Chef & Assistant Professor
#
#
#
#
# URL 2: https://aaft.com/bsc-in-sound-design
# Course Faculty 2:
# Dr Manoj Agarwal
# Director
#
# Dr Parth Sinha
# Dean & COE
#
# Ms. Tanya Sharma
# HOD
#
# Mr. Mohit Arora
# Assistant Professor
#
# Mr. Kunal Shourie
# Assistant Professor
#
# Mr. Shubham Raj
# Assistant Professor
#
# Mr. Vaibhav Chaudhary
# Assistant Professor
#
# Mr. Shashank Gautam
# Assistant Professor
#
# Mr. Umesh Bisht
# Assistant Professor
#
# Mr. Abdullah Khan
# Assistant Professor
#
# Mr. Mohit Kumar
# Operation’s Manager
#
# Mr. Himanshu Mehta
# Assistant professor
#
# Ms. Shraddha Gupta
# Assistant professor
#
#
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_course_faculty(urls):
    data = []
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            faculty_section = soup.find("section", id="faculty-section")
            if faculty_section:
                faculty_items = faculty_section.find_all("div", class_="col-sm-3")
                course_faculty = ""
                for item in faculty_items:
                    faculty_name = item.find("h4").text.strip()
                    faculty_role = item.find("span").text.strip()
                    course_faculty += f"{faculty_name}\n{faculty_role}\n\n"
                data.append({"URL": url, "Course Faculty": course_faculty})
            else:
                data.append({"URL": url, "Course Faculty": "Course faculty details not found on the page."})
        else:
            data.append({"URL": url, "Course Faculty": f"Failed to fetch the page. Status code: {response.status_code}"})
    
    return data

# List of URLs to extract "Course Faculty" information from
url_list = [
"https://aaft.com/1-year-diploma-in-culinary-arts",
"https://aaft.com/bsc-in-sound-design",
"https://aaft.com/pg-diploma-in-tv-journalism-and-communication",
"https://aaft.com/schoolofinterior/programmes/pg-diploma-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-design",
"https://aaft.com/schooloffashion/programmes/one-year-diploma-course-in-fashion-communication",
"https://aaft.com/ma-classical-vocal",
"https://aaft.com/ma-in-still-photography",
"https://aaft.com/msc-interior-design",
"https://aaft.com/msc-in-game-design-and-development",
"https://aaft.com/schooloffashion/programmes/masters-in-fashion-design-2-yrs",
"https://aaft.com/msc-in-data-science",
"https://aaft.com/schoolofanimation/programmes/m-sc-in-3d-animation",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-sound-editing",
"https://aaft.com/msc-in-cinema-and-pg-diploma-in-Post-Production(Video)",
"https://aaft.com/msc-in-digital-marketing",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-direction",
"https://aaft.com/schoolofcinema/m-sc-cinema-pg-diploma-in-cinematography",
"https://aaft.com/schoolofmasscommunication/programmes/ma-mass-communication",
"https://aaft.com/schoolofadvertising/programmes/ma-public-relations-events",
"https://aaft.com/schoolofadvertising/programmes/ma-advertising-brand-communication",
"https://aaft.com/diploma-in-westen-vocal-instrument",
"https://aaft.com/diploma-in-unreal-engine",
"https://aaft.com/schoolofmasscommunication/programmes/pgd-in-tv-journalism-communication",
"https://aaft.com/Diploma-in-tourism-and-travel",
"https://aaft.com/schoolofphotography/diploma-pg-diploma-in-photography",
"https://aaft.com/diploma-in-sound-design",
"https://aaft.com/diploma-in-pr-and-events",
"https://aaft.com/schoolofcinema/programmes/diploma-in-post-production",
"https://aaft.com/diploma-in-music-production",
"https://aaft.com/diploma-in-interior-design",
"https://aaft.com/diploma-in-instrumental-western-classical",
"https://aaft.com/schooloffinearts/diploma-in-classical-vocal-instrument",
"https://aaft.com/diploma-in-hotel-management",
"https://aaft.com/diploma-in-film-and-tv-production",
"https://aaft.com/schooloffashion/fashion-at-aaft",
"https://aaft.com/diploma-in-fashion-communication",
"https://aaft.com/diploma-in-djing",
"https://aaft.com/diploma-in-digital-marketing",
"https://aaft.com/diploma-in-data-science",
"https://aaft.com/6-months-diploma-in-culinary-arts",
"https://aaft.com/diploma-in-indian-classical-vocal-instrument",
"https://aaft.com/schoolofcinema/programmes/diploma-in-camera-lightning-techniques",
"https://aaft.com/diploma-in-animation-and-vfx",
"https://aaft.com/diploma-in-advertising-and-brand-communication",
"https://aaft.com/diploma-in-acting-and-presentation",
"https://aaft.com/diploma-in-sound-designing-3months",
"https://aaft.com/diploma-in-music-production-3months",
"https://aaft.com/schoolofcinema/video-editing-sound-recording",
"https://aaft.com/certificate-in-still-photography",
"https://aaft.com/schoolofcinema/programmes/screenplay-writing",
"https://aaft.com/schoolofmasscommunication/radio-jockey-rj",
"https://aaft.com/schoolofcinema/production-direction-tv-journalism",
"https://aaft.com/schoolofmasscommunication/news-anchoring-reporting",
"https://aaft.com/certificate-in-graphic-design",
"https://aaft.com/certificate-in-digital-marketing",
"https://aaft.com/certificate-in-camera-and-lighting-techniques",
"https://aaft.com/bachelors-of-tourism-and-travel-management",
"https://aaft.com/bachelors-of-hotel-management",
"https://aaft.com/schooloffinearts/programmes/bachelor-in-performing-arts",
"https://aaft.com/certificate-course-in-bakery",
"https://aaft.com/ba-in-indian-classical-vocal",
"https://aaft.com/ba-instrumental-music-guitar",
"https://aaft.com/schoolofadvertising/ba-in-event-management",
"https://aaft.com/schoolofinterior/programmes/b-sc-interior-design-diploma-in-interior-design",
"https://aaft.com/schoolofanimation/b-sc-in-game-design-development",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-communication-b-des-fashion-communication",
"https://aaft.com/bsc-in-digital-marketing",
"https://aaft.com/bsc-in-data-science",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-sound-editing",
"https://aaft.com/bsc-in-cinema-and-diploma-in-Post-Production(Video)",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-direction",
"https://aaft.com/schoolofcinema/b-sc-cinema-diploma-in-cinematography",
"https://aaft.com/schoolofanimation/programmes/b-sc-in-3d-animation",
"https://aaft.com/schooloffashion/programmes/fashion-design",
"https://aaft.com/schoolofinterior/programmes/b-des-interior-design-diploma-in-interior-design",
"https://aaft.com/schooloffashion/programmes/bachelor-in-fashion-design-b-des-fashion-design",
"https://aaft.com/ba-in-still-photography",
"https://aaft.com/ba-in-journalism-and-mass-communication",
"https://aaft.com/1-year-diploma-in-culinary-arts",

    # Add more URLs here
]

extracted_data = extract_course_faculty(url_list)

# Create a DataFrame from the extracted data
df = pd.DataFrame(extracted_data)

# Export the DataFrame to an Excel file
excel_file = "AAFTcourse_faculty.xlsx"
df.to_excel(excel_file, index=False)

print(f"Data extracted and saved to '{excel_file}'")
# Out:
# Data extracted and saved to 'AAFTcourse_faculty.xlsx'
